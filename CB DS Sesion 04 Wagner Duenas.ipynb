# %%
import pandas as pd

# %%
df = pd.read_csv("sales_and_dates.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 412698 entries, 0 to 412697
# Data columns (total 2 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date       412698 non-null  object
#  1   SalePrice  412698 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 6.3+ MB

# %%
df=pd.read_csv("sales_and_dates.csv", parse_dates=["Date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 412698 entries, 0 to 412697
# Data columns (total 2 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date       412698 non-null  datetime64[ns]
#  1   SalePrice  412698 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 6.3 MB

# %%
df.head()
# Out:
#         Date  SalePrice
# 0 2006-11-16    66000.0
# 1 2004-03-26    57000.0
# 2 2004-02-26    10000.0
# 3 2011-05-19    38500.0
# 4 2009-07-23    11000.0

# %%
df.Date.min()
# Out:
# Timestamp('1989-01-17 00:00:00')

# %%
df.Date.max()
# Out:
# Timestamp('2012-04-28 00:00:00')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
january_december =df[(df["Date"].dt.month==1)|(df["Date"].dt.month==12)]["SalePrice"]

# %%
df.head()
# Out:
#         Date  SalePrice
# 0 2006-11-16    66000.0
# 1 2004-03-26    57000.0
# 2 2004-02-26    10000.0
# 3 2011-05-19    38500.0
# 4 2009-07-23    11000.0

# %%
df["Date"].dt.month
# Out:
# 0         11
# 1          3
# 2          2
# 3          5
# 4          7
#           ..
# 412693     3
# 412694     1
# 412695     1
# 412696     3
# 412697     1
# Name: Date, Length: 412698, dtype: int32

# %%
df['trimestre'] = df.Date.dt.quarter

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df["is_friday"] = 0
df.loc[df.Date.dt.day_of_week==4,'is_friday'] = 1

# %%
df.head(10)
# Out:
#         Date  SalePrice  trimestre  is_friday
# 0 2006-11-16    66000.0          4          0
# 1 2004-03-26    57000.0          1          1
# 2 2004-02-26    10000.0          1          0
# 3 2011-05-19    38500.0          2          0
# 4 2009-07-23    11000.0          3          0
# 5 2008-12-18    26500.0          4          0
# 6 2004-08-26    21000.0          3          0
# 7 2005-11-17    27000.0          4          0
# 8 2009-08-27    21500.0          3          0
# 9 2007-08-09    65000.0          3          0

# %%
df[["SalePrice", "is_friday"]].groupby('is_friday').mean()
# Out:
#               SalePrice
# is_friday
# 0          31327.695053
# 1          30275.553713

# %% [markdown]
# Pillar el promedio de ventas pro trimestra

# %%
df.set_index('Date',inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 412698 entries, 2006-11-16 to 2012-01-28
# Data columns (total 3 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   SalePrice  412698 non-null  float64
#  1   trimestre  412698 non-null  int32
#  2   is_friday  412698 non-null  int64
# dtypes: float64(1), int32(1), int64(1)
# memory usage: 11.0 MB
