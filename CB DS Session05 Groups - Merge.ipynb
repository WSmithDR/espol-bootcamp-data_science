# %%
import pandas as pd

# %%
dg = pd.read_csv("diputados_gastos.csv", sep=";", encoding='ISO-8859-1')
# Out:
# C:\Users\smithinator\AppData\Local\Temp\ipykernel_64040\1806839885.py:1: DtypeWarning: Columns (10,11,13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   dg = pd.read_csv("diputados_gastos.csv", sep=";", encoding='ISO-8859-1')

# %%
m
# Out:
#        cod_diputado estado partido    descripcion  \
# 0              sen1     TO     DEM  FLIGHT TICKET
# 1              sen2     BA     DEM     FUEL COSTS
# 2              sen2     BA     DEM     FUEL COSTS
# 3              sen2     BA     DEM     FUEL COSTS
# 4              sen2     BA     DEM     FUEL COSTS
# ...             ...    ...     ...            ...
# 339084          NaN    NaN     NaN     MEAL COSTS
# 339085          NaN    NaN     NaN     MEAL COSTS
# 339086          NaN    NaN     NaN     MEAL COSTS
# 339087          NaN    NaN     NaN     MEAL COSTS
# 339088          NaN    NaN     NaN     MEAL COSTS
#
#                                        empresa id_empresa  \
# 0                            Cia Aï¿½rea - TAM   2,01E+23
# 1       CASCOL COMBUSTIVEIS PARA VEICULOS LTDA   3,07E+22
# 2       CASCOL COMBUSTIVEIS PARA VEICULOS LTDA   3,07E+22
# 3                MEGA POSTO BERIMBAU LTDA - ME   1,86E+22
# 4                MEGA POSTO BERIMBAU LTDA - ME   1,86E+22
# ...

# %%
dg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 339089 entries, 0 to 339088
# Data columns (total 17 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   cod_diputado        338198 non-null  object
#  1   estado              338198 non-null  object
#  2   partido             338198 non-null  object
#  3   descripcion         339089 non-null  object
#  4   empresa             339089 non-null  object
#  5   id_empresa          296821 non-null  object
#  6   fecha_reembolso     332744 non-null  object
#  7   valor_reembolso     339086 non-null  float64
#  8   partido_tipo        339086 non-null  object
#  9   partido_en          339086 non-null  object
#  10  partido_tse         339086 non-null  object
#  11  partido_nmembers    339086 non-null  object
#  12  partido_ideologia1  339086 non-null  object
#  13  partido_ideologia2  288405 non-null  object
#  14  partido_ideology3   165643 non-null  object
# ...

# %%
sub_set = dg[["cod_diputado","estado","partido","descripcion","empresa","fecha_reembolso","valor_reembolso" ]]

# %%
sub_set
# Out:
#        cod_diputado estado partido    descripcion  \
# 0              sen1     TO     DEM  FLIGHT TICKET
# 1              sen2     BA     DEM     FUEL COSTS
# 2              sen2     BA     DEM     FUEL COSTS
# 3              sen2     BA     DEM     FUEL COSTS
# 4              sen2     BA     DEM     FUEL COSTS
# ...             ...    ...     ...            ...
# 339084          NaN    NaN     NaN     MEAL COSTS
# 339085          NaN    NaN     NaN     MEAL COSTS
# 339086          NaN    NaN     NaN     MEAL COSTS
# 339087          NaN    NaN     NaN     MEAL COSTS
# 339088          NaN    NaN     NaN     MEAL COSTS
#
#                                        empresa      fecha_reembolso  \
# 0                            Cia Aï¿½rea - TAM  2016-07-29T00:00:00
# 1       CASCOL COMBUSTIVEIS PARA VEICULOS LTDA  2016-06-21T00:00:00
# 2       CASCOL COMBUSTIVEIS PARA VEICULOS LTDA  2016-06-01T00:00:00
# 3                MEGA POSTO BERIMBAU LTDA - ME  2016-04-19T00:00:00
# ...

# %%
sub_set["descripcion"].value_counts()
# Out:
# descripcion
# FLIGHT TICKET                                    102373
# FUEL COSTS                                        71353
# PHONE COSTS                                       33498
# MAIL COSTS                                        28100
# MEAL COSTS                                        26042
# TAXI, PARKING AND TOLL COSTS                      25899
# OFFICE MAINTENANCE                                23365
# DISSEMINATION OF PARLIAMENTARY ACTIVITY           10146
# GROUND VEHICLE RENT                                6217
# HOTEL COSTS                                        5885
# CONSULTING, RESEARCH AND TECHNICAL WORK COSTS      2898
# PUBLICATION SIGNATURE EXPENSES                     1077
# SECURITY SERVICE                                    932
# GROUND TRANSPORTATION TICKET                        894
# AIRPLANE RENT                                       344
# WORKSHOP/COURSE/EVENT COSTS                          36
# SHIP/BOAT RENT                                       30
# ...

# %%
sub_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 339089 entries, 0 to 339088
# Data columns (total 7 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   cod_diputado     338198 non-null  object
#  1   estado           338198 non-null  object
#  2   partido          338198 non-null  object
#  3   descripcion      339089 non-null  object
#  4   empresa          339089 non-null  object
#  5   fecha_reembolso  332744 non-null  object
#  6   valor_reembolso  339086 non-null  float64
# dtypes: float64(1), object(6)
# memory usage: 18.1+ MB

# %%
sub_set.columns = ['cod_diputado', 'estado', 'partido', 'categoria', 'empresa',
       'fecha_reembolso',"valor_reembolso"]

# %%
sub_set.columns
# Out:
# Index(['cod_diputado', 'estado', 'partido', 'categoria', 'empresa',
#        'fecha_reembolso', 'valor_reembolso'],
#       dtype='object')

# %%
sub_set.isna().sum()
# Out:
# cod_diputado        891
# estado              891
# partido             891
# categoria             0
# empresa               0
# fecha_reembolso    6345
# valor_reembolso       3
# dtype: int64

# %%
sub_set.dropna(inplace=True)
# Out:
# C:\Users\smithinator\AppData\Local\Temp\ipykernel_64040\2556075580.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_set.dropna(inplace=True)

# %%
sub_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 331853 entries, 0 to 338197
# Data columns (total 7 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   cod_diputado     331853 non-null  object
#  1   estado           331853 non-null  object
#  2   partido          331853 non-null  object
#  3   categoria        331853 non-null  object
#  4   empresa          331853 non-null  object
#  5   fecha_reembolso  331853 non-null  object
#  6   valor_reembolso  331853 non-null  float64
# dtypes: float64(1), object(6)
# memory usage: 20.3+ MB

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
hotel_waste = sub_set[sub_set.categoria == "HOTEL COSTS"]

# %%
hotel_wastes_by_state = hotel_waste.groupby("estado")['valor_reembolso'].sum().sort_values(ascending=False)

# %%
hotel_wastes_by_state.head()
# Out:
# estado
# PR    273133.75
# MG    217678.81
# SC    168143.32
# RS    164214.92
# BA    154976.37
# Name: valor_reembolso, dtype: float64

# %%
hotel_wastes_by_state.index
# Out:
# Index(['PR', 'MG', 'SC', 'RS', 'BA', 'SP', 'MA', 'PE', 'MT', 'PI', 'MS', 'RJ',
#        'PA', 'CE', 'GO', 'RO', 'AC', 'RR', 'PB', 'AM', 'AL', 'TO', 'ES', 'SE',
#        'RN', 'AP', 'DF'],
#       dtype='object', name='estado')

# %%
hotel_wastes_by_state.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_64040\120716348.py in ?()
# ----> 1 hotel_wastes_by_state.columns
#
# c:\Projects\Espol\espol-bootcamp-data_science\data_science_venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'columns'
